# %% [markdown]
# # Example run: MAGICC
#
# Here we demonstrate how to run with MAGICC. We run with the IPs from WG3 and demonstrate that the results in the database can be reproduced. However, other input data could be used for custom scenario runs.
#
# For more information, see the docs associated with the MAGICC model.

# %% [markdown]
# ## Setup logging
#
# Pyam does its own logging stuff, so we have to configure logging before that import.

# %%
import logging

# Increase the level to reduce the number of log messages
LOGGING_LEVEL = logging.INFO

LOGGER = logging.getLogger("pipeline")
LOGGER.setLevel(LOGGING_LEVEL)
# have to set root logger too to get messages to come through
logging.getLogger().setLevel(LOGGING_LEVEL)

logFormatter = logging.Formatter(
    "%(asctime)s %(name)s %(threadName)s - %(levelname)s:  %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
)
stdoutHandler = logging.StreamHandler()
stdoutHandler.setFormatter(logFormatter)

logging.getLogger().addHandler(stdoutHandler)

# %% [markdown]
# ## Other imports

# %%
import os.path

import dotenv
import matplotlib.pyplot as plt
import pandas as pd
import pandas.testing as pdt
import pooch
import pyam
import tempfile

from climate_assessment.cli import run_workflow
# Out:
# 2024-12-06 16:05:49 pint.util MainThread - WARNING:  Redefining 'kt' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:49 pint.util MainThread - WARNING:  Redefining 'EUR_2005' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:50 pint.util MainThread - WARNING:  Redefining 'EUR' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\scmdata\database\_database.py:9: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   import tqdm.autonotebook as tqdman
# 2024-12-06 16:05:51 pint.util MainThread - WARNING:  Redefining 'C' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:51 pint.util MainThread - WARNING:  Redefining 'N' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:51 pint.util MainThread - WARNING:  Redefining 'NOX' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:51 pint.util MainThread - WARNING:  Redefining 'gNOX' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:51 pint.util MainThread - WARNING:  Redefining 'tNOX' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:51 pint.util MainThread - WARNING:  Redefining 'S' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:52 pint.util MainThread - WARNING:  Redefining 'yr' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:52 pint.util MainThread - WARNING:  Redefining 'a' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:52 pint.util MainThread - WARNING:  Redefining 'h' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:52 pint.util MainThread - WARNING:  Redefining 'd' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:52 pint.util MainThread - WARNING:  Redefining 'degreeC' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:52 pint.util MainThread - WARNING:  Redefining 'degreeF' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:52 pint.util MainThread - WARNING:  Redefining 'kt' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:52 pint.util MainThread - WARNING:  Redefining 'Tt' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:52 pint.util MainThread - WARNING:  Redefining 'ppm' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:54 pint.util MainThread - WARNING:  Redefining 'C' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:54 pint.util MainThread - WARNING:  Redefining 'N' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:54 pint.util MainThread - WARNING:  Redefining 'NOX' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:54 pint.util MainThread - WARNING:  Redefining 'gNOX' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:54 pint.util MainThread - WARNING:  Redefining 'tNOX' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:54 pint.util MainThread - WARNING:  Redefining 'S' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:54 pint.util MainThread - WARNING:  Redefining 'yr' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:54 pint.util MainThread - WARNING:  Redefining 'a' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:54 pint.util MainThread - WARNING:  Redefining 'h' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:54 pint.util MainThread - WARNING:  Redefining 'd' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:54 pint.util MainThread - WARNING:  Redefining 'degreeC' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:54 pint.util MainThread - WARNING:  Redefining 'degreeF' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:54 pint.util MainThread - WARNING:  Redefining 'kt' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:54 pint.util MainThread - WARNING:  Redefining 'Tt' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# 2024-12-06 16:05:54 pint.util MainThread - WARNING:  Redefining 'ppm' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)

# %%
dotenv.load_dotenv()
# Out:
# True

# %% [markdown]
# ## Configuration of input data

# %% [markdown]
# ### Download model and configuration

# %% [markdown]
# The MAGICC model and configuration is available at [magicc.org](https://magicc.org/), where you can also download the parameter set used in AR6. Please read the license and expectations carefully, we rely on users to act in a way which brings both new scientific outcomes but also acknowledges the work put into the MAGICC AR6 setup.
#
# After you have downloaded the tar files, please extract it (we typically extract MAGICC and the probabilistic distribution into `magicc-files` in the root directory).
#
# The set of commands on a unix-like system is given below (PRs to add the Windows equivalent are welcome).

# %%
# The variables can be taken from an environment (.env) file or simply set here
# Just replace the links with the ones you receive from www.magicc.org
# os.environ["MAGICC_LINK_FROM_MAGICC_DOT_ORG"] = "www.magicc.org/api/download?type=MAGICC7&token=tok"
# os.environ["MAGICC_PROB_DISTRIBUTION_LINK_FROM_MAGICC_DOT_ORG"] = "www.magicc.org/api/download?type=AR6_PROBABILISTIC&token=tok"
# os.environ["MAGICC_ROOT_FILES_DIR"] = os.path.join("..", "magicc-files")
os.environ["MAGICC_ROOT_FILES_DIR"] = r"C:\Users\tonnru\lab\MAGICC7"
print(f'MAGICC_ROOT_FILES_DIR = {os.environ["MAGICC_ROOT_FILES_DIR"]}')
# Out:
# MAGICC_ROOT_FILES_DIR = C:\Users\tonnru\lab\MAGICC7

# %% [markdown]
# The cell below downloads and sets up MAGICC on a linux system. It can be skipped once it has been run once (and will need to be modified for a windows system).

# %%
# # MAGICC binary
# !mkdir -p "${MAGICC_ROOT_FILES_DIR}"/magicc-v7.5.3
# !wget -O "${MAGICC_ROOT_FILES_DIR}/magicc-v7.5.3.tar.gz" "${MAGICC_LINK_FROM_MAGICC_DOT_ORG}"
# !tar -xf "${MAGICC_ROOT_FILES_DIR}/magicc-v7.5.3.tar.gz" -C "${MAGICC_ROOT_FILES_DIR}/magicc-v7.5.3"

# # Probabilistic distribution
# !mkdir -p "${MAGICC_ROOT_FILES_DIR}/magicc-ar6-0fd0f62-f023edb-drawnset"
# !wget -O "${MAGICC_ROOT_FILES_DIR}/magicc-ar6-0fd0f62-f023edb-drawnset.tar.gz" "${MAGICC_PROB_DISTRIBUTION_LINK_FROM_MAGICC_DOT_ORG}"
# !tar -xf "${MAGICC_ROOT_FILES_DIR}/magicc-ar6-0fd0f62-f023edb-drawnset.tar.gz" -C "${MAGICC_ROOT_FILES_DIR}/magicc-ar6-0fd0f62-f023edb-drawnset"

# %% [markdown]
# ### Set model input paths
#
# Here we tell the pipeline where to look for MAGICC and where to create parallel workers on disk.

# %%
# Where is the binary
os.environ["MAGICC_EXECUTABLE_7"] = os.path.join(
    os.environ["MAGICC_ROOT_FILES_DIR"], "magicc-v7.5.3", "bin", 
    "magicc.exe" if os.name == "nt" else "magicc7"
)

# How many MAGICC workers can run in parallel?
os.environ["MAGICC_WORKER_NUMBER"] = "4"

# Where should the MAGICC workers be located on the filesystem (you need about
# 500Mb space per worker at the moment, they're removed after use)
os.environ["MAGICC_WORKER_ROOT_DIR"] = tempfile.gettempdir()


print(f'MAGICC_EXECUTABLE_7 = {os.environ["MAGICC_EXECUTABLE_7"]}')
print(f'MAGICC_WORKER_ROOT_DIR = {os.environ["MAGICC_WORKER_ROOT_DIR"]}')
# Out:
# MAGICC_EXECUTABLE_7 = C:\Users\tonnru\lab\MAGICC7\magicc-v7.5.3\bin\magicc.exe
# MAGICC_WORKER_ROOT_DIR = C:\Users\tonnru\AppData\Local\Temp

# %% [markdown]
# ### Set general input arguments and options to the climate assessment workflow
#
# The values we've set below will let you run MAGICC and reproduce the AR6 WG3 results.

# %%
model = "magicc"
model_version = "v7.5.3"
probabilistic_file = os.path.join(
    os.environ["MAGICC_ROOT_FILES_DIR"],
    "magicc-ar6-0fd0f62-f023edb-drawnset",
    "0fd0f62-derived-metrics-id-f023edb-drawnset.json",
)
probabilistic_file = r"C:\Users\tonnru\lab\MAGICC7\magicc-ar6-0fd0f62-f023edb-drawnset\0fd0f62-derived-metrics-id-f023edb-drawnset.json"
print(os.path.exists(probabilistic_file))

# Use fewer (e.g. 10) if you just want to do a test run but note that this breaks
# the stats of the probabilistic ensemble
num_cfgs = 600
# Set to True if you're not using the full MAGICC ensemble
test_run = False
# How many scenarios do you want to run in one go?
scenario_batch_size = 20

# Where should the output be saved?
outdir = os.path.join("..", "data", "output-magicc-example-notebook")
outdir = os.path.realpath(outdir)
print(os.path.exists(outdir))
print(outdir)
# Out:
# True
# True
# C:\Users\tonnru\lab\climate-assessment\data\output-magicc-example-notebook

# %% [markdown]
# ### Choose input emissions pathway file
#
# By default, we use 2 of the AR6 IPs. You could use a different file (formatted the same way) if you wish.

# %%
# EMISSIONS_DATA_DIR = os.path.join("..", "tests", "test-data")
# EMISSIONS_INPUT_FILE = "ar6_IPs_emissions.csv"

# input_emissions_file = os.path.join(EMISSIONS_DATA_DIR, EMISSIONS_INPUT_FILE)
input_emissions_file = (
    r"C:\Users\tonnru\lab\climate-assessment\tests\test-data\ar6_IPs_emissions.csv"
)

# %% [markdown]
# ### Choose infiller database file
#
# We run using the infiller database that was used in CMIP6. As a result of the licensing of the scenario data, this file has to be downloaded by hand (see documentation under "Installation", section "Infiller database"). Make sure that the variable `infilling_database_file` points to where you saved this file.

# %%
# infilling_database_file = os.path.join(
#     "..",
#     "data",
#     "1652361598937-ar6_emissions_vetted_infillerdatabase_10.5281-zenodo.6390768.csv",
# )
infilling_database_file = r"C:\Users\tonnru\lab\climate-assessment\tests\test-data\cmip6-ssps-workflow-emissions_infillerdatabase_until2100.csv"

# %% [markdown]
# ## Run the climate assessment workflow

# %% [markdown]
# *N.B. the log with information and some warnings will be quite long - but that is nothing to worry about!*

# %%
run_workflow(
    input_emissions_file,
    outdir,
    model=model,
    model_version=model_version,
    probabilistic_file=probabilistic_file,
    num_cfgs=num_cfgs,
    infilling_database=infilling_database_file,
    scenario_batch_size=scenario_batch_size,
)
# Out:
# 2024-12-06 16:05:55 climate_assessment.cli MainThread - INFO:  Outputs will be saved in: C:\Users\tonnru\lab\climate-assessment\data\output-magicc-example-notebook
# 2024-12-06 16:05:55 climate_assessment.cli MainThread - INFO:  Outputs will be saved with the ID: ar6_IPs_emissions
# 2024-12-06 16:05:55 climate_assessment.cli MainThread - INFO:  Loading C:\Users\tonnru\lab\climate-assessment\tests\test-data\ar6_IPs_emissions.csv
# [INFO] 16:05:55 - pyam.core: Reading file C:\Users\tonnru\lab\climate-assessment\tests\test-data\ar6_IPs_emissions.csv
# 2024-12-06 16:05:55 pyam.core MainThread - INFO:  Reading file C:\Users\tonnru\lab\climate-assessment\tests\test-data\ar6_IPs_emissions.csv
# c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\pyam\utils.py:318: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   .stack(dropna=True)
# 2024-12-06 16:05:55 climate_assessment.cli MainThread - INFO:  Converting to basic columns i.e. removing any extra columns
# 2024-12-06 16:05:55 climate_assessment.cli MainThread - INFO:  Performing input data checks
# 2024-12-06 16:05:55 climate_assessment.checks MainThread - INFO:  CHECK: if no non-co2 negatives are reported.
# c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\pyam\core.py:895: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   self.meta[name] = meta[name].combine_first(self.meta[name])
# [WARNING] 16:05:55 - pyam.core: Filtered IamDataFrame is empty!
# 2024-12-06 16:05:55 pyam.core MainThread - WARNING:  Filtered IamDataFrame is empty!
# 2024-12-06 16:05:55 climate_assessment.checks MainThread - INFO:  CHECK: report emissions for all minimally required years.
# c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\pyam\utils.py:318: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   .stack(dropna=True)
# [WARNING] 16:05:55 - pyam.utils: Formatted data is empty.
# 2024-12-06 16:05:55 pyam.utils MainThread - WARNING:  Formatted data is empty.
# c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\pyam\utils.py:318: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   .stack(dropna=True)
# 2024-12-06 16:05:55 climate_assessment.checks MainThread - INFO:  CHECK: combine E&IP if reported separately.
# 2024-12-06 16:05:55 climate_assessment.checks MainThread - INFO:  CHECK: reclassify Waste and Other CO2 under E&IP.
# 2024-12-06 16:05:55 climate_assessment.checks MainThread - INFO:  CHECK: delete rows only reporting zero for the entire timeframe.
# 2024-12-06 16:05:56 climate_assessment.checks MainThread - INFO:
# ==================================
# Removing the following timeseries
# because they report zero in every
# timestep.
# ==================================
#                                                                                   2010  \
# model                 scenario              region variable            unit
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000 World  Emissions|NH3|AFOLU Mt NH3/yr   0.0
#                                                    Emissions|NH3|Waste Mt NH3/yr   0.0
#                                                    Emissions|OC|Other  Mt OC/yr    0.0
#
#                                                                                   2015  \
# model                 scenario              region variable            unit
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000 World  Emissions|NH3|AFOLU Mt NH3/yr   0.0
#                                                    Emissions|NH3|Waste Mt NH3/yr   0.0
#                                                    Emissions|OC|Other  Mt OC/yr    0.0
#
#                                                                                   2020  \
# model                 scenario              region variable            unit
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000 World  Emissions|NH3|AFOLU Mt NH3/yr   0.0
#                                                    Emissions|NH3|Waste Mt NH3/yr   0.0
#                                                    Emissions|OC|Other  Mt OC/yr    0.0
#
#                                                                                   2025  \
# model                 scenario              region variable            unit
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000 World  Emissions|NH3|AFOLU Mt NH3/yr   0.0
#                                                    Emissions|NH3|Waste Mt NH3/yr   0.0
#                                                    Emissions|OC|Other  Mt OC/yr    0.0
#
#                                                                                   2030  \
# model                 scenario              region variable            unit
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000 World  Emissions|NH3|AFOLU Mt NH3/yr   0.0
#                                                    Emissions|NH3|Waste Mt NH3/yr   0.0
#                                                    Emissions|OC|Other  Mt OC/yr    0.0
#
#                                                                                   2035  \
# model                 scenario              region variable            unit
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000 World  Emissions|NH3|AFOLU Mt NH3/yr   0.0
#                                                    Emissions|NH3|Waste Mt NH3/yr   0.0
#                                                    Emissions|OC|Other  Mt OC/yr    0.0
#
#                                                                                   2040  \
# model                 scenario              region variable            unit
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000 World  Emissions|NH3|AFOLU Mt NH3/yr   0.0
#                                                    Emissions|NH3|Waste Mt NH3/yr   0.0
#                                                    Emissions|OC|Other  Mt OC/yr    0.0
#
#                                                                                   2045  \
# model                 scenario              region variable            unit
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000 World  Emissions|NH3|AFOLU Mt NH3/yr   0.0
#                                                    Emissions|NH3|Waste Mt NH3/yr   0.0
#                                                    Emissions|OC|Other  Mt OC/yr    0.0
#
#                                                                                   2050  \
# model                 scenario              region variable            unit
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000 World  Emissions|NH3|AFOLU Mt NH3/yr   0.0
#                                                    Emissions|NH3|Waste Mt NH3/yr   0.0
#                                                    Emissions|OC|Other  Mt OC/yr    0.0
#
#                                                                                   2055  \
# model                 scenario              region variable            unit
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000 World  Emissions|NH3|AFOLU Mt NH3/yr   0.0
#                                                    Emissions|NH3|Waste Mt NH3/yr   0.0
#                                                    Emissions|OC|Other  Mt OC/yr    0.0
#
#                                                                                   2060  \
# model                 scenario              region variable            unit
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000 World  Emissions|NH3|AFOLU Mt NH3/yr   0.0
#                                                    Emissions|NH3|Waste Mt NH3/yr   0.0
#                                                    Emissions|OC|Other  Mt OC/yr    0.0
#
#                                                                                   2065  \
# model                 scenario              region variable            unit
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000 World  Emissions|NH3|AFOLU Mt NH3/yr   NaN
#                                                    Emissions|NH3|Waste Mt NH3/yr   NaN
#                                                    Emissions|OC|Other  Mt OC/yr    NaN
#
#                                                                                   2070  \
# model                 scenario              region variable            unit
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000 World  Emissions|NH3|AFOLU Mt NH3/yr   0.0
#                                                    Emissions|NH3|Waste Mt NH3/yr   0.0
#                                                    Emissions|OC|Other  Mt OC/yr    0.0
#
#                                                                                   2075  \
# model                 scenario              region variable            unit
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000 World  Emissions|NH3|AFOLU Mt NH3/yr   NaN
#                                                    Emissions|NH3|Waste Mt NH3/yr   NaN
#                                                    Emissions|OC|Other  Mt OC/yr    NaN
#
#                                                                                   2080  \
# model                 scenario              region variable            unit
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000 World  Emissions|NH3|AFOLU Mt NH3/yr   0.0
#                                                    Emissions|NH3|Waste Mt NH3/yr   0.0
#                                                    Emissions|OC|Other  Mt OC/yr    0.0
#
#                                                                                   2085  \
# model                 scenario              region variable            unit
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000 World  Emissions|NH3|AFOLU Mt NH3/yr   NaN
#                                                    Emissions|NH3|Waste Mt NH3/yr   NaN
#                                                    Emissions|OC|Other  Mt OC/yr    NaN
#
#                                                                                   2090  \
# model                 scenario              region variable            unit
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000 World  Emissions|NH3|AFOLU Mt NH3/yr   0.0
#                                                    Emissions|NH3|Waste Mt NH3/yr   0.0
#                                                    Emissions|OC|Other  Mt OC/yr    0.0
#
#                                                                                   2095  \
# model                 scenario              region variable            unit
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000 World  Emissions|NH3|AFOLU Mt NH3/yr   NaN
#                                                    Emissions|NH3|Waste Mt NH3/yr   NaN
#                                                    Emissions|OC|Other  Mt OC/yr    NaN
#
#                                                                                   2100
# model                 scenario              region variable            unit
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000 World  Emissions|NH3|AFOLU Mt NH3/yr   0.0
#                                                    Emissions|NH3|Waste Mt NH3/yr   0.0
#                                                    Emissions|OC|Other  Mt OC/yr    0.0
# 2024-12-06 16:05:56 climate_assessment.checks MainThread - INFO:  CHECK: check if co2 lead variables are reported.
# 2024-12-06 16:05:56 climate_assessment.checks MainThread - INFO:  Emissions|CO2 is provided in addition to Emissions|CO2|Energy and Industrial Processes and Emissions|CO2|AFOLU for scenario `NGFS2_Current Policies` produced by `GCAM 5.3` hence is removed to avoid any potential inconsistencies being introduced during harmonization
# 2024-12-06 16:05:56 climate_assessment.checks MainThread - INFO:  Emissions|CO2 is provided in addition to Emissions|CO2|Energy and Industrial Processes and Emissions|CO2|AFOLU for scenario `SusDev_SDP-PkBudg1000` produced by `REMIND-MAgPIE 2.1-4.2` hence is removed to avoid any potential inconsistencies being introduced during harmonization
# 2024-12-06 16:05:56 climate_assessment.harmonization MainThread - INFO:  Using ar6 instance for harmonization
# 2024-12-06 16:05:56 scmdata.run MainThread - INFO:  Reading C:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\climate_assessment\harmonization\history_ar6.csv
# 2024-12-06 16:05:56 climate_assessment.harmonization MainThread - INFO:  Not harmonizing {'Emissions|Sulfur|Energy|Supply', 'Emissions|CO2|Energy|Demand|Transportation|Road|Passenger|LDV', 'Emissions|CF4', 'Emissions|VOC|Energy|Supply', 'Emissions|CH4|AFOLU|Agriculture', 'Emissions|VOC|Energy|Demand|Residential and Commercial', 'Emissions|CO|Energy|Demand|Industry', 'Emissions|CO2|Energy|Supply|Solids', 'Emissions|BC|Waste', 'Emissions|BC|Energy|Demand|Transportation', 'Emissions|CO2|Energy|Demand|Residential and Commercial|Commercial', 'Emissions|BC|Energy', 'Emissions|CO2|Energy|Demand', 'Emissions|BC|Energy|Demand|Industry', 'Emissions|NOx|Other', 'Emissions|CH4|AFOLU', 'Emissions|Sulfur|Energy|Demand|Residential and Commercial', 'Emissions|CO|Energy', 'Emissions|NH3|Energy|Supply', 'Emissions|CO2|Energy|Demand|Transportation', 'Emissions|NOx|Energy|Demand|Residential and Commercial', 'Emissions|CH4|AFOLU|Agriculture|Livestock', 'Emissions|Sulfur|AFOLU', 'Emissions|CH4|AFOLU|Agriculture|Livestock|Enteric Fermentation', 'Emissions|CO2|Energy|Supply|Liquids', 'Emissions|N2O|Other', 'Emissions|Sulfur|Energy|Demand|Industry', 'Emissions|N2O|Energy|Demand|Transportation', 'Emissions|NOx|Energy|Demand|Industry', 'Emissions|CH4|Other', 'Emissions|CH4|Energy|Demand|Transportation', 'Emissions|CO2|Energy|Supply|Electricity', 'Emissions|BC|Energy|Supply', 'Emissions|C2F6', 'Emissions|CO2|Energy|Demand|Industry', 'Emissions|VOC|Waste', 'Emissions|NOx|Energy', 'Emissions|N2O|AFOLU|Agriculture', 'Emissions|OC|Energy|Demand|Residential and Commercial', 'Emissions|CO2|Energy|Supply', 'Emissions|NH3|AFOLU', 'Emissions|CH4|AFOLU|Agriculture|Rice', 'Emissions|CO|Waste', 'Emissions|NOx|Energy|Demand|Transportation', 'Emissions|N2O|AFOLU|Agriculture|Managed Soils', 'Emissions|CO|AFOLU', 'Emissions|OC|Energy|Demand|Transportation', 'Emissions|CO2|Energy|Demand|Transportation|Passenger', 'Emissions|VOC|Energy|Demand|Transportation', 'Emissions|N2O|Industrial Processes', 'Emissions|VOC|Energy', 'Emissions|CO2|Energy|Demand|Residential and Commercial|Residential', 'Emissions|NH3|Energy|Demand|Industry', 'Emissions|NOx|Energy|Supply', 'Emissions|CO|Other', 'Emissions|CO2|Energy', 'Emissions|CO|Energy|Demand|Transportation', 'Emissions|CH4|Energy|Supply', 'Emissions|CO2|Energy|Supply|Heat', 'Emissions|CO2|Energy|Demand|Transportation|Freight', 'Emissions|NH3|Energy|Demand|Transportation', 'Emissions|Sulfur|Waste', 'Emissions|CO2|Energy|Supply|Other Sector', 'Emissions|OC|AFOLU', 'Emissions|N2O|Waste', 'Emissions|CH4|Energy|Demand|Residential and Commercial', 'Emissions|BC|Other', 'Emissions|CO|Energy|Demand|Residential and Commercial', 'Emissions|N2O|Energy', 'Emissions|NH3|Energy', 'Emissions|OC|Energy|Demand|Industry', 'Emissions|Sulfur|Energy|Demand|Transportation', 'Emissions|OC|Energy', 'Emissions|N2O|AFOLU|Agriculture|Livestock|Manure Management', 'Emissions|OC|Energy|Supply', 'Emissions|NOx|AFOLU', 'Emissions|VOC|Other', 'Emissions|BC|AFOLU', 'Emissions|CO|Energy|Supply', 'Emissions|CH4|Energy', 'Emissions|CO2|Energy|Supply|Gases', 'Emissions|CO2|Energy|Demand|Residential and Commercial', 'Emissions|VOC|AFOLU', 'Emissions|NOx|Waste', 'Emissions|CO2|Industrial Processes', 'Emissions|VOC|Energy|Demand|Industry', 'Emissions|NH3|Energy|Demand|Residential and Commercial', 'Emissions|CH4|AFOLU|Agriculture|Livestock|Manure Management', 'Emissions|CH4|Energy|Demand|Industry', 'Emissions|BC|Energy|Demand|Residential and Commercial', 'Emissions|Sulfur|Other', 'Emissions|Sulfur|Energy', 'Emissions|OC|Waste', 'Emissions|N2O|AFOLU', 'Emissions|NH3|Other', 'Emissions|HFC|HFC245fa', 'Emissions|CH4|Waste'}
# 2024-12-06 16:05:56 climate_assessment.harmonization MainThread - INFO:  harmonization_year 2015
# 2024-12-06 16:05:56 climate_assessment.harmonization MainThread - INFO:  Stripping equivalent units for processing
# 2024-12-06 16:05:56 climate_assessment.harmonization MainThread - INFO:  Creating pd.DataFrame's for aneris
# 2024-12-06 16:05:56 climate_assessment.harmonization MainThread - INFO:  Adding 2015 values based on historical percentage offset from 2010
# 2024-12-06 16:05:56 climate_assessment.harmonization MainThread - INFO:  Interpolating onto output timesteps
# 2024-12-06 16:05:56 climate_assessment.harmonization MainThread - INFO:  Harmonisation overrides:
#                     method                                       variable
# 0    reduce_ratio_2150_cov                                  Emissions|PFC
# 1    reduce_ratio_2150_cov                             Emissions|PFC|C2F6
# 2    reduce_ratio_2150_cov                            Emissions|PFC|C6F14
# 3    reduce_ratio_2150_cov                              Emissions|PFC|CF4
# 4    reduce_ratio_2150_cov                                   Emissions|CO
# 5        reduce_ratio_2080                                  Emissions|CO2
# 6   reduce_offset_2150_cov                            Emissions|CO2|AFOLU
# 7        reduce_ratio_2080  Emissions|CO2|Energy and Industrial Processes
# 8           constant_ratio                              Emissions|F-Gases
# 9           constant_ratio                                  Emissions|HFC
# 10          constant_ratio                           Emissions|HFC|HFC125
# 11          constant_ratio                          Emissions|HFC|HFC134a
# 12          constant_ratio                          Emissions|HFC|HFC143a
# 13          constant_ratio                         Emissions|HFC|HFC227ea
# 14          constant_ratio                            Emissions|HFC|HFC23
# 15          constant_ratio                            Emissions|HFC|HFC32
# 16          constant_ratio                         Emissions|HFC|HFC43-10
# 17   reduce_ratio_2150_cov                                   Emissions|OC
# 18          constant_ratio                                  Emissions|SF6
# 19   reduce_ratio_2150_cov                                  Emissions|VOC
# Harmonisation: 0it [00:00, ?it/s]2024-12-06 16:05:56 climate_assessment.harmonization MainThread - INFO:  Harmonising in parallel
# Harmonisation: 2it [00:05,  2.50s/it]
# 2024-12-06 16:06:01 climate_assessment.harmonization MainThread - INFO:  Hacking around some regression in aneris - pyam stack
# 2024-12-06 16:06:01 climate_assessment.harmonization MainThread - INFO:  Combining results
# 2024-12-06 16:06:01 climate_assessment.harmonization MainThread - INFO:  Putting equiv back in units
# 2024-12-06 16:06:01 climate_assessment.harmonization MainThread - INFO:  Converting to IamDataFrame
# c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\pyam\utils.py:318: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   .stack(dropna=True)
# 2024-12-06 16:06:01 climate_assessment.harmonization MainThread - INFO:  CHECK: if some emissions are zero in the harmonization year.
# 2024-12-06 16:06:01 climate_assessment.infilling MainThread - INFO:  Infilling database: C:\Users\tonnru\lab\climate-assessment\tests\test-data\cmip6-ssps-workflow-emissions_infillerdatabase_until2100.csv
# 2024-12-06 16:06:01 climate_assessment.infilling MainThread - INFO:  CFC infilling database: c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\climate_assessment\infilling\cmip6-ssps-workflow-emissions.csv
# 2024-12-06 16:06:01 climate_assessment.infilling MainThread - INFO:  Loading infilling database
# 2024-12-06 16:06:01 scmdata.run MainThread - INFO:  Reading C:\Users\tonnru\lab\climate-assessment\tests\test-data\cmip6-ssps-workflow-emissions_infillerdatabase_until2100.csv
# 2024-12-06 16:06:01 climate_assessment.infilling MainThread - INFO:  Loading infilling database cfcs
# 2024-12-06 16:06:01 scmdata.run MainThread - INFO:  Reading c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\climate_assessment\infilling\cmip6-ssps-workflow-emissions.csv
# 2024-12-06 16:06:01 climate_assessment.infilling MainThread - INFO:  Preparing infilling databases
# [WARNING] 16:06:01 - pyam.core: Filtered IamDataFrame is empty!
# 2024-12-06 16:06:01 pyam.core MainThread - WARNING:  Filtered IamDataFrame is empty!
# [WARNING] 16:06:01 - pyam.core: Filtered IamDataFrame is empty!
# 2024-12-06 16:06:01 pyam.core MainThread - WARNING:  Filtered IamDataFrame is empty!
# 2024-12-06 16:06:01 climate_assessment.infilling MainThread - INFO:  Infilling using ['Emissions|CO2'] as the lead variable
# [WARNING] 16:06:01 - pyam.core: Filtered IamDataFrame is empty!
# 2024-12-06 16:06:01 pyam.core MainThread - WARNING:  Filtered IamDataFrame is empty!
# [WARNING] 16:06:01 - pyam.core: Filtered IamDataFrame is empty!
# 2024-12-06 16:06:01 pyam.core MainThread - WARNING:  Filtered IamDataFrame is empty!
# 2024-12-06 16:06:01 climate_assessment.infilling MainThread - INFO:  Nothing to infill
# 2024-12-06 16:06:01 climate_assessment.infilling MainThread - INFO:  Infilling using ['Emissions|CO2|Energy and Industrial Processes'] as the lead variable
# [WARNING] 16:06:01 - pyam.core: Filtered IamDataFrame is empty!
# 2024-12-06 16:06:01 pyam.core MainThread - WARNING:  Filtered IamDataFrame is empty!
# 2024-12-06 16:06:01 climate_assessment.infilling MainThread - INFO:  Interpolating data to infill
# 2024-12-06 16:06:01 climate_assessment.infilling MainThread - INFO:  Infilling using cruncher <class 'silicone.database_crunchers.quantile_rolling_windows.QuantileRollingWindows'>
# 2024-12-06 16:06:01 climate_assessment.infilling MainThread - INFO:  Infilling ['Emissions|BC', 'Emissions|CH4', 'Emissions|CO2|AFOLU', 'Emissions|CO', 'Emissions|N2O', 'Emissions|NH3', 'Emissions|NOx', 'Emissions|OC', 'Emissions|Sulfur', 'Emissions|VOC']
# Filling required variables:   0%|          | 0/10 [00:00<?, ?it/s]c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\silicone\database_crunchers\quantile_rolling_windows.py:182: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   wide_db = wide_db.applymap(lambda x: np.nan if isinstance(x, str) else x)
# c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\pyam\core.py:895: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   self.meta[name] = meta[name].combine_first(self.meta[name])
# Filling required variables:  10%|█         | 1/10 [00:00<00:04,  1.86it/s]c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\silicone\database_crunchers\quantile_rolling_windows.py:182: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   wide_db = wide_db.applymap(lambda x: np.nan if isinstance(x, str) else x)
# Filling required variables:  20%|██        | 2/10 [00:01<00:04,  1.95it/s]c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\silicone\database_crunchers\quantile_rolling_windows.py:182: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   wide_db = wide_db.applymap(lambda x: np.nan if isinstance(x, str) else x)
# Filling required variables:  30%|███       | 3/10 [00:01<00:03,  1.97it/s]c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\silicone\database_crunchers\quantile_rolling_windows.py:182: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   wide_db = wide_db.applymap(lambda x: np.nan if isinstance(x, str) else x)
# Filling required variables:  40%|████      | 4/10 [00:02<00:03,  1.87it/s]c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\silicone\database_crunchers\quantile_rolling_windows.py:182: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   wide_db = wide_db.applymap(lambda x: np.nan if isinstance(x, str) else x)
# Filling required variables:  50%|█████     | 5/10 [00:02<00:02,  1.93it/s]c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\silicone\database_crunchers\quantile_rolling_windows.py:182: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   wide_db = wide_db.applymap(lambda x: np.nan if isinstance(x, str) else x)
# Filling required variables:  60%|██████    | 6/10 [00:03<00:02,  1.87it/s]c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\silicone\database_crunchers\quantile_rolling_windows.py:182: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   wide_db = wide_db.applymap(lambda x: np.nan if isinstance(x, str) else x)
# Filling required variables:  70%|███████   | 7/10 [00:03<00:01,  1.87it/s]c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\silicone\database_crunchers\quantile_rolling_windows.py:182: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   wide_db = wide_db.applymap(lambda x: np.nan if isinstance(x, str) else x)
# Filling required variables:  80%|████████  | 8/10 [00:04<00:01,  1.87it/s]c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\silicone\database_crunchers\quantile_rolling_windows.py:182: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   wide_db = wide_db.applymap(lambda x: np.nan if isinstance(x, str) else x)
# Filling required variables:  90%|█████████ | 9/10 [00:04<00:00,  1.88it/s]c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\silicone\database_crunchers\quantile_rolling_windows.py:182: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   wide_db = wide_db.applymap(lambda x: np.nan if isinstance(x, str) else x)
# Filling required variables: 100%|██████████| 10/10 [00:05<00:00,  1.88it/s]
# 2024-12-06 16:06:07 climate_assessment.infilling MainThread - INFO:  Infilling using cruncher <class 'silicone.database_crunchers.rms_closest.RMSClosest'>
# 2024-12-06 16:06:07 climate_assessment.infilling MainThread - INFO:  Infilling ['Emissions|HFC|HFC134a', 'Emissions|HFC|HFC143a', 'Emissions|HFC|HFC227ea', 'Emissions|HFC|HFC23', 'Emissions|HFC|HFC32', 'Emissions|HFC|HFC43-10', 'Emissions|HFC|HFC245ca', 'Emissions|HFC|HFC125', 'Emissions|SF6', 'Emissions|PFC|CF4', 'Emissions|PFC|C2F6', 'Emissions|PFC|C6F14']
# c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\silicone\multiple_infillers\infill_all_required_emissions_for_openscm.py:188: UserWarning: No data for ['Emissions|HFC|HFC245ca'], it will be infilled with 0s
#   warnings.warn(
# 2024-12-06 16:06:07 silicone.database_crunchers.constant_ratio MainThread - INFO:  <class 'silicone.database_crunchers.constant_ratio.ConstantRatio'> won't use any information from the database
# Filling required variables:   0%|          | 0/1 [00:00<?, ?it/s]c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\pyam\core.py:895: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   self.meta[name] = meta[name].combine_first(self.meta[name])
# 2024-12-06 16:06:07 silicone.database_crunchers.constant_ratio MainThread - WARNING:  Note that the lead variable ['Emissions|CO2|Energy and Industrial Processes'] goes negative.
# Filling required variables: 100%|██████████| 1/1 [00:00<00:00, 30.05it/s]
# Note that the lead variable ['Emissions|CO2|Energy and Industrial Processes'] goes negative.
# Filling required variables: 100%|██████████| 11/11 [00:01<00:00, 10.02it/s]
# 2024-12-06 16:06:08 climate_assessment.infilling MainThread - INFO:  Infilling using cruncher <class 'silicone.database_crunchers.rms_closest.RMSClosest'>
# 2024-12-06 16:06:08 climate_assessment.infilling MainThread - INFO:  Infilling ['Emissions|CCl4', 'Emissions|CFC11', 'Emissions|CFC113', 'Emissions|CFC114', 'Emissions|CFC115', 'Emissions|CFC12', 'Emissions|CH2Cl2', 'Emissions|CH3Br', 'Emissions|CH3CCl3', 'Emissions|CH3Cl', 'Emissions|CHCl3', 'Emissions|HCFC141b', 'Emissions|HCFC142b', 'Emissions|HCFC22', 'Emissions|HFC|HFC152a', 'Emissions|HFC|HFC236fa', 'Emissions|HFC|HFC365mfc', 'Emissions|Halon1202', 'Emissions|Halon1211', 'Emissions|Halon1301', 'Emissions|Halon2402', 'Emissions|NF3', 'Emissions|PFC|C3F8', 'Emissions|PFC|C4F10', 'Emissions|PFC|C5F12', 'Emissions|PFC|C7F16', 'Emissions|PFC|C8F18', 'Emissions|PFC|cC4F8', 'Emissions|SO2F2']
# Filling required variables:   0%|          | 0/29 [00:00<?, ?it/s]c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\pyam\core.py:895: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   self.meta[name] = meta[name].combine_first(self.meta[name])
# Filling required variables: 100%|██████████| 29/29 [00:02<00:00, 11.01it/s]
# 2024-12-06 16:06:11 climate_assessment.infilling MainThread - INFO:  Converting HFC/PFC units back from CO2-equivalent
# 2024-12-06 16:06:14 climate_assessment.infilling MainThread - INFO:  Post-processing for climate models
# 2024-12-06 16:06:14 climate_assessment.infilling MainThread - INFO:  Checking infilled results have required years and variables
# 2024-12-06 16:06:14 climate_assessment.infilling MainThread - INFO:  Check that there are no non-CO2 negatives introduced by infilling
# c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\pyam\core.py:895: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   self.meta[name] = meta[name].combine_first(self.meta[name])
# 2024-12-06 16:06:14 climate_assessment.harmonization_and_infilling MainThread - INFO:  Writing infilled data as csv to: C:\Users\tonnru\lab\climate-assessment\data\output-magicc-example-notebook\ar6_IPs_emissions_harmonized_infilled.csv
# 2024-12-06 16:06:14 climate_assessment.harmonization_and_infilling MainThread - INFO:  Writing infilled data as xlsx to: C:\Users\tonnru\lab\climate-assessment\data\output-magicc-example-notebook\ar6_IPs_emissions_harmonized_infilled.xlsx
# c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\pyam\utils.py:85: FutureWarning: Starting with pandas version 3.0 all arguments of to_excel except for the argument 'excel_writer' will be keyword-only.
#   df.to_excel(writer, name, index=False)
# c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\pyam\utils.py:85: FutureWarning: Starting with pandas version 3.0 all arguments of to_excel except for the argument 'excel_writer' will be keyword-only.
#   df.to_excel(writer, name, index=False)
# 2024-12-06 16:06:14 climate_assessment.cli MainThread - INFO:  Reading in infilled scenarios from: C:\Users\tonnru\lab\climate-assessment\data\output-magicc-example-notebook\ar6_IPs_emissions_harmonized_infilled.csv
# c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\pyam\utils.py:318: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   .stack(dropna=True)
# 2024-12-06 16:06:14 climate_assessment.cli MainThread - INFO:                                                                                                                              2015  \
# model                 scenario               region variable                                           unit
# GCAM 5.3              NGFS2_Current Policies World  AR6 climate diagnostics|Harmonized|Emissions|BC    Mt BC/yr         9.727424
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CH4   Mt CH4/yr      388.072796
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO    Mt CO/yr       934.349885
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr     3517.440000
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr    35635.286300
# ...                                                                                                                          ...
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000  World  AR6 climate diagnostics|Infilled|Emissions|PFC|... kt cC4F8/yr      1.267200
#                                                     AR6 climate diagnostics|Infilled|Emissions|SF6     kt SF6/yr        8.020000
#                                                     AR6 climate diagnostics|Infilled|Emissions|SO2F2   kt SO2F2/yr      2.531700
#                                                     AR6 climate diagnostics|Infilled|Emissions|Sulfur  Mt SO2/yr      100.771167
#                                                     AR6 climate diagnostics|Infilled|Emissions|VOC     Mt VOC/yr      227.244819
#
#                                                                                                                             2016  \
# model                 scenario               region variable                                           unit
# GCAM 5.3              NGFS2_Current Policies World  AR6 climate diagnostics|Harmonized|Emissions|BC    Mt BC/yr         9.486864
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CH4   Mt CH4/yr      389.042537
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO    Mt CO/yr       908.729608
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr     3615.570662
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr    35894.212790
# ...                                                                                                                          ...
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000  World  AR6 climate diagnostics|Infilled|Emissions|PFC|... kt cC4F8/yr      1.304749
#                                                     AR6 climate diagnostics|Infilled|Emissions|SF6     kt SF6/yr        7.877059
#                                                     AR6 climate diagnostics|Infilled|Emissions|SO2F2   kt SO2F2/yr      2.606677
#                                                     AR6 climate diagnostics|Infilled|Emissions|Sulfur  Mt SO2/yr       98.981399
#                                                     AR6 climate diagnostics|Infilled|Emissions|VOC     Mt VOC/yr      225.156160
#
#                                                                                                                             2017  \
# model                 scenario               region variable                                           unit
# GCAM 5.3              NGFS2_Current Policies World  AR6 climate diagnostics|Harmonized|Emissions|BC    Mt BC/yr         9.247408
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CH4   Mt CH4/yr      390.012519
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO    Mt CO/yr       883.100412
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr     3713.701324
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr    36153.051290
# ...                                                                                                                          ...
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000  World  AR6 climate diagnostics|Infilled|Emissions|PFC|... kt cC4F8/yr      1.342401
#                                                     AR6 climate diagnostics|Infilled|Emissions|SF6     kt SF6/yr        7.734117
#                                                     AR6 climate diagnostics|Infilled|Emissions|SO2F2   kt SO2F2/yr      2.681859
#                                                     AR6 climate diagnostics|Infilled|Emissions|Sulfur  Mt SO2/yr       97.197819
#                                                     AR6 climate diagnostics|Infilled|Emissions|VOC     Mt VOC/yr      223.076129
#
#                                                                                                                             2018  \
# model                 scenario               region variable                                           unit
# GCAM 5.3              NGFS2_Current Policies World  AR6 climate diagnostics|Harmonized|Emissions|BC    Mt BC/yr         9.009056
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CH4   Mt CH4/yr      390.982741
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO    Mt CO/yr       857.462298
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr     3811.831986
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr    36411.801799
# ...                                                                                                                          ...
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000  World  AR6 climate diagnostics|Infilled|Emissions|PFC|... kt cC4F8/yr      1.379951
#                                                     AR6 climate diagnostics|Infilled|Emissions|SF6     kt SF6/yr        7.591176
#                                                     AR6 climate diagnostics|Infilled|Emissions|SO2F2   kt SO2F2/yr      2.756835
#                                                     AR6 climate diagnostics|Infilled|Emissions|Sulfur  Mt SO2/yr       95.420427
#                                                     AR6 climate diagnostics|Infilled|Emissions|VOC     Mt VOC/yr      221.004727
#
#                                                                                                                             2019  \
# model                 scenario               region variable                                           unit
# GCAM 5.3              NGFS2_Current Policies World  AR6 climate diagnostics|Harmonized|Emissions|BC    Mt BC/yr         8.771808
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CH4   Mt CH4/yr      391.953202
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO    Mt CO/yr       831.815266
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr     3909.962648
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr    36670.464317
# ...                                                                                                                          ...
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000  World  AR6 climate diagnostics|Infilled|Emissions|PFC|... kt cC4F8/yr      1.417500
#                                                     AR6 climate diagnostics|Infilled|Emissions|SF6     kt SF6/yr        7.448234
#                                                     AR6 climate diagnostics|Infilled|Emissions|SO2F2   kt SO2F2/yr      2.831812
#                                                     AR6 climate diagnostics|Infilled|Emissions|Sulfur  Mt SO2/yr       93.649222
#                                                     AR6 climate diagnostics|Infilled|Emissions|VOC     Mt VOC/yr      218.941952
#
#                                                                                                                             2020  \
# model                 scenario               region variable                                           unit
# GCAM 5.3              NGFS2_Current Policies World  AR6 climate diagnostics|Harmonized|Emissions|BC    Mt BC/yr         8.535663
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CH4   Mt CH4/yr      392.923903
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO    Mt CO/yr       806.159314
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr     4008.093310
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr    36929.038844
# ...                                                                                                                          ...
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000  World  AR6 climate diagnostics|Infilled|Emissions|PFC|... kt cC4F8/yr      1.455049
#                                                     AR6 climate diagnostics|Infilled|Emissions|SF6     kt SF6/yr        7.305293
#                                                     AR6 climate diagnostics|Infilled|Emissions|SO2F2   kt SO2F2/yr      2.906789
#                                                     AR6 climate diagnostics|Infilled|Emissions|Sulfur  Mt SO2/yr       91.884205
#                                                     AR6 climate diagnostics|Infilled|Emissions|VOC     Mt VOC/yr      216.887805
#
#                                                                                                                             2021  \
# model                 scenario               region variable                                           unit
# GCAM 5.3              NGFS2_Current Policies World  AR6 climate diagnostics|Harmonized|Emissions|BC    Mt BC/yr         8.438927
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CH4   Mt CH4/yr      395.864307
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO    Mt CO/yr       798.133375
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr     3794.498511
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr    37405.419069
# ...                                                                                                                          ...
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000  World  AR6 climate diagnostics|Infilled|Emissions|PFC|... kt cC4F8/yr      1.357357
#                                                     AR6 climate diagnostics|Infilled|Emissions|SF6     kt SF6/yr        6.984609
#                                                     AR6 climate diagnostics|Infilled|Emissions|SO2F2   kt SO2F2/yr      2.711653
#                                                     AR6 climate diagnostics|Infilled|Emissions|Sulfur  Mt SO2/yr       86.401659
#                                                     AR6 climate diagnostics|Infilled|Emissions|VOC     Mt VOC/yr      210.345750
#
#                                                                                                                             2022  \
# model                 scenario               region variable                                           unit
# GCAM 5.3              NGFS2_Current Policies World  AR6 climate diagnostics|Harmonized|Emissions|BC    Mt BC/yr         8.342578
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CH4   Mt CH4/yr      398.805464
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO    Mt CO/yr       790.104613
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr     3580.903711
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr    37881.638851
# ...                                                                                                                          ...
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000  World  AR6 climate diagnostics|Infilled|Emissions|PFC|... kt cC4F8/yr      1.259932
#                                                     AR6 climate diagnostics|Infilled|Emissions|SF6     kt SF6/yr        6.663926
#                                                     AR6 climate diagnostics|Infilled|Emissions|SO2F2   kt SO2F2/yr      2.517049
#                                                     AR6 climate diagnostics|Infilled|Emissions|Sulfur  Mt SO2/yr       80.939892
#                                                     AR6 climate diagnostics|Infilled|Emissions|VOC     Mt VOC/yr      203.840862
#
#                                                                                                                             2023  \
# model                 scenario               region variable                                           unit
# GCAM 5.3              NGFS2_Current Policies World  AR6 climate diagnostics|Harmonized|Emissions|BC    Mt BC/yr         8.246615
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CH4   Mt CH4/yr      401.747374
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO    Mt CO/yr       782.073029
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr     3367.308912
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr    38357.698191
# ...                                                                                                                          ...
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000  World  AR6 climate diagnostics|Infilled|Emissions|PFC|... kt cC4F8/yr      1.162506
#                                                     AR6 climate diagnostics|Infilled|Emissions|SF6     kt SF6/yr        6.343243
#                                                     AR6 climate diagnostics|Infilled|Emissions|SO2F2   kt SO2F2/yr      2.322446
#                                                     AR6 climate diagnostics|Infilled|Emissions|Sulfur  Mt SO2/yr       75.498904
#                                                     AR6 climate diagnostics|Infilled|Emissions|VOC     Mt VOC/yr      197.373142
#
#                                                                                                                             2024  \
# ...
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO    Mt CO/yr       581.866299
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr    -3078.471320
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr    53304.098020
# ...                                                                                                                          ...
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000  World  AR6 climate diagnostics|Infilled|Emissions|PFC|... kt cC4F8/yr      0.122343
#                                                     AR6 climate diagnostics|Infilled|Emissions|SF6     kt SF6/yr        2.979649
#                                                     AR6 climate diagnostics|Infilled|Emissions|SO2F2   kt SO2F2/yr      0.244526
#                                                     AR6 climate diagnostics|Infilled|Emissions|Sulfur  Mt SO2/yr       10.540000
#                                                     AR6 climate diagnostics|Infilled|Emissions|VOC     Mt VOC/yr       90.419443
#
#                                                                                                                             2096  \
# model                 scenario               region variable                                           unit
# GCAM 5.3              NGFS2_Current Policies World  AR6 climate diagnostics|Harmonized|Emissions|BC    Mt BC/yr         5.227633
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CH4   Mt CH4/yr      430.773001
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO    Mt CO/yr       581.785429
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr    -3059.061165
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr    53043.043760
# ...                                                                                                                          ...
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000  World  AR6 climate diagnostics|Infilled|Emissions|PFC|... kt cC4F8/yr      0.119418
#                                                     AR6 climate diagnostics|Infilled|Emissions|SF6     kt SF6/yr        3.125084
#                                                     AR6 climate diagnostics|Infilled|Emissions|SO2F2   kt SO2F2/yr      0.238696
#                                                     AR6 climate diagnostics|Infilled|Emissions|Sulfur  Mt SO2/yr       10.457420
#                                                     AR6 climate diagnostics|Infilled|Emissions|VOC     Mt VOC/yr       89.885386
#
#                                                                                                                             2097  \
# model                 scenario               region variable                                           unit
# GCAM 5.3              NGFS2_Current Policies World  AR6 climate diagnostics|Harmonized|Emissions|BC    Mt BC/yr         5.210577
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CH4   Mt CH4/yr      428.698347
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO    Mt CO/yr       581.704497
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr    -3039.651010
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr    52781.989500
# ...                                                                                                                          ...
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000  World  AR6 climate diagnostics|Infilled|Emissions|PFC|... kt cC4F8/yr      0.116484
#                                                     AR6 climate diagnostics|Infilled|Emissions|SF6     kt SF6/yr        3.270519
#                                                     AR6 climate diagnostics|Infilled|Emissions|SO2F2   kt SO2F2/yr      0.232851
#                                                     AR6 climate diagnostics|Infilled|Emissions|Sulfur  Mt SO2/yr       10.374840
#                                                     AR6 climate diagnostics|Infilled|Emissions|VOC     Mt VOC/yr       89.352653
#
#                                                                                                                             2098  \
# model                 scenario               region variable                                           unit
# GCAM 5.3              NGFS2_Current Policies World  AR6 climate diagnostics|Harmonized|Emissions|BC    Mt BC/yr         5.193521
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CH4   Mt CH4/yr      426.623694
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO    Mt CO/yr       581.623504
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr    -3020.240855
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr    52520.935240
# ...                                                                                                                          ...
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000  World  AR6 climate diagnostics|Infilled|Emissions|PFC|... kt cC4F8/yr      0.113559
#                                                     AR6 climate diagnostics|Infilled|Emissions|SF6     kt SF6/yr        3.415953
#                                                     AR6 climate diagnostics|Infilled|Emissions|SO2F2   kt SO2F2/yr      0.227021
#                                                     AR6 climate diagnostics|Infilled|Emissions|Sulfur  Mt SO2/yr       10.292260
#                                                     AR6 climate diagnostics|Infilled|Emissions|VOC     Mt VOC/yr       88.821245
#
#                                                                                                                             2099  \
# model                 scenario               region variable                                           unit
# GCAM 5.3              NGFS2_Current Policies World  AR6 climate diagnostics|Harmonized|Emissions|BC    Mt BC/yr         5.176466
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CH4   Mt CH4/yr      424.549040
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO    Mt CO/yr       581.542450
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr    -3000.830700
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr    52259.880980
# ...                                                                                                                          ...
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000  World  AR6 climate diagnostics|Infilled|Emissions|PFC|... kt cC4F8/yr      0.110633
#                                                     AR6 climate diagnostics|Infilled|Emissions|SF6     kt SF6/yr        3.561388
#                                                     AR6 climate diagnostics|Infilled|Emissions|SO2F2   kt SO2F2/yr      0.221192
#                                                     AR6 climate diagnostics|Infilled|Emissions|Sulfur  Mt SO2/yr       10.209680
#                                                     AR6 climate diagnostics|Infilled|Emissions|VOC     Mt VOC/yr       88.291163
#
#                                                                                                                             2100
# model                 scenario               region variable                                           unit
# GCAM 5.3              NGFS2_Current Policies World  AR6 climate diagnostics|Harmonized|Emissions|BC    Mt BC/yr         5.159410
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CH4   Mt CH4/yr      422.474386
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO    Mt CO/yr       581.461334
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr    -2981.420546
#                                                     AR6 climate diagnostics|Harmonized|Emissions|CO... Mt CO2/yr    51998.826720
# ...                                                                                                                          ...
# REMIND-MAgPIE 2.1-4.2 SusDev_SDP-PkBudg1000  World  AR6 climate diagnostics|Infilled|Emissions|PFC|... kt cC4F8/yr      0.107708
#                                                     AR6 climate diagnostics|Infilled|Emissions|SF6     kt SF6/yr        3.706823
#                                                     AR6 climate diagnostics|Infilled|Emissions|SO2F2   kt SO2F2/yr      0.215362
#                                                     AR6 climate diagnostics|Infilled|Emissions|Sulfur  Mt SO2/yr       10.127100
#                                                     AR6 climate diagnostics|Infilled|Emissions|VOC     Mt VOC/yr       87.762404
#
# [146 rows x 86 columns]
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 run_workflow(
#       2     input_emissions_file,
#       3     outdir,
#       4     model=model,
#       5     model_version=model_version,
#       6     probabilistic_file=probabilistic_file,
#       7     num_cfgs=num_cfgs,
#       8     infilling_database=infilling_database_file,
#       9     scenario_batch_size=scenario_batch_size,
#      10 )
#
# File c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\climate_assessment\cli.py:622, in run_workflow(input_emissions_file, outdir, model, model_version, probabilistic_file, num_cfgs, inputcheck, magicc_extra_config, fair_extra_config, historical_warming, historical_warming_reference_period, historical_warming_evaluation_period, test_run, scenario_batch_size, infilling_database, save_raw_climate_output, postprocess, categorisation, reporting_completeness_categorisation, harmonize, prefix, harmonization_instance, co2_and_non_co2_warming, gwp)
#     617 LOGGER.info(df_infilled.timeseries())
#     619 ####################
#     620 # run climate models
#     621 ####################
# --> 622 df_climate = climate_assessment(
#     623     df_infilled,
#     624     key_string,
#     625     outdir,
#     626     magicc_extra_config=magicc_extra_config,
#     627     fair_extra_config=fair_extra_config,
#     628     model=model,
#     629     model_version=model_version,
#     630     probabilistic_file=probabilistic_file,
#     631     num_cfgs=num_cfgs,
#     632     historical_warming=historical_warming,
#     633     historical_warming_reference_period=historical_warming_reference_period,
#     634     historical_warming_evaluation_period=historical_warming_evaluation_period,
#     635     test_run=test_run,
#     636     scenario_batch_size=scenario_batch_size,
#     637     save_raw_output=save_raw_climate_output,
#     638     co2_and_non_co2_warming=co2_and_non_co2_warming,
#     639     prefix=prefix,
#     640 )
#     641 LOGGER.info(df_climate.timeseries())
#     643 LOGGER.info("Concatenating infilled df, climate df and input df")
#
# File c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\climate_assessment\climate\__init__.py:127, in climate_assessment(df, key_string, outdir, model, model_version, num_cfgs, historical_warming, historical_warming_reference_period, historical_warming_evaluation_period, test_run, scenario_batch_size, save_raw_output, probabilistic_file, magicc_extra_config, fair_extra_config, co2_and_non_co2_warming, prefix, year_filter_first, year_filter_last)
#     124 if clean_scenarios is None:
#     125     return None
# --> 127 climate_model_cfgs, climate_models_out_config = _get_model_configs_and_out_configs(
#     128     model=model,
#     129     model_version=model_version,
#     130     probabilistic_file=probabilistic_file,
#     131     magicc_extra_config=magicc_extra_config,
#     132     fair_extra_config=fair_extra_config,
#     133     num_cfgs=num_cfgs,
#     134     co2_and_non_co2_warming=co2_and_non_co2_warming,
#     135 )
#     137 # define auxiliary functions to circumvent the big memory requirements
#     138 #   for storing in pyam long format
#     139 def add_batch_id_to_outpath(ipath):
#
# File c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\climate_assessment\climate\__init__.py:439, in _get_model_configs_and_out_configs(model, model_version, probabilistic_file, magicc_extra_config, fair_extra_config, num_cfgs, co2_and_non_co2_warming)
#     437 if model_version is None:
#     438     model_version = DEFAULT_MAGICC_VERSION
# --> 439 magicc7_cfgs, magicc7_out_config = get_magicc7_configurations(
#     440     magicc_version=model_version,
#     441     magicc_probabilistic_file=probabilistic_file,
#     442     magicc_extra_config=magicc_extra_config,
#     443     num_cfgs=num_cfgs,
#     444     co2_and_non_co2_warming=co2_and_non_co2_warming,
#     445 )
#     446 climate_model_cfgs["MAGICC7"] = magicc7_cfgs
#     447 climate_models_out_config = {"MAGICC7": magicc7_out_config}
#
# File c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\climate_assessment\climate\magicc7.py:22, in get_magicc7_configurations(magicc_version, magicc_probabilistic_file, magicc_extra_config, num_cfgs, co2_and_non_co2_warming)
#      12 def get_magicc7_configurations(
#      13     magicc_version,
#      14     magicc_probabilistic_file,
#    (...)
#      17     co2_and_non_co2_warming,
#      18 ):
#      19     """
#      20     Get configuration for MAGICC7
#      21     """
# ---> 22     if MAGICC7.get_version() != magicc_version:
#      23         # version strings for linux and windows might be different!
#      24         raise AssertionError(MAGICC7.get_version())
#      26     with open(magicc_probabilistic_file) as fh:
#
# File c:\Users\tonnru\lab\envs\scm_conda\Lib\site-packages\openscm_runner\adapters\magicc7\magicc7.py:220, in MAGICC7.get_version(cls)
#     209 @classmethod
#     210 def get_version(cls):
#     211     """
#     212     Get the MAGICC7 version being used by this adapter
#     213
#    (...)
#     217         The MAGICC7 version id
#     218     """
#     219     return (
# --> 220         check_output([cls._executable(), "--version"])  # nosec
#     221         .decode("utf-8")
#     222         .strip()
#     223     )
#
# File c:\Users\tonnru\lab\envs\scm_conda\Lib\subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     463         empty = b''
#     464     kwargs['input'] = empty
# --> 466 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     467            **kwargs).stdout
#
# File c:\Users\tonnru\lab\envs\scm_conda\Lib\subprocess.py:571, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     569     retcode = process.poll()
#     570     if check and retcode:
# --> 571         raise CalledProcessError(retcode, process.args,
#     572                                  output=stdout, stderr=stderr)
#     573 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['C:\\Users\\tonnru\\lab\\MAGICC7\\magicc-v7.5.3\\bin\\magicc.exe', '--version']' returned non-zero exit status 3221225595.

# %% [markdown]
# ### Load results
#
# *N.B The filename will likely have changed if you have run your own scenarios.*

# %%
output = pyam.IamDataFrame(os.path.join(outdir, "ar6_IPs_emissions_alloutput.xlsx"))
output

# %% [markdown]
# ### Compare with database results
#
# These would normally need to be downloaded, but we include a set in the repository for testing. Here we check that we have reproduced the database results. Obviously, this should be skipped if you have run a custom scenario.

# %%
expected_output_file = os.path.join(
    "..", "tests", "test-data", "expected-output-wg3/two_ips_climate_magicc.xlsx"
)

expected_db_output = pyam.IamDataFrame(expected_output_file).timeseries()

# The database does not necessarily include all the outputs we have
test_output = output.timeseries().loc[expected_db_output.index, :]

# Check that we reproduce values
pdt.assert_frame_equal(
    test_output,
    expected_db_output,
    rtol=1e-3,
    atol=1e-3,
)

# %% [markdown]
# ### Some basic exploration

# %% [markdown]
# Look at the scenario categories.

# %%
output.meta["Category"]

# %% [markdown]
# Make a plot of median warming.

# %%
ax = output.filter(variable="*|Surface Temperature (GSAT)|*|50.0th Percentile").plot(
    color="scenario"
)
plt.title("Global warming above the 1850-1900 mean")
ax.set_xlim([1995, 2100])

# %% [markdown]
# ## Conclusion
#
# That's it! You just ran a a full climate assessment workflow going from emissions to temperature (and more) using the functionality from the climate-assessment package, and then visualised the results.
#
# It is also possible to run from the command line, and build more elaborate workflows. For that, please see the extended documentation.
